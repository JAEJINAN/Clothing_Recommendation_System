# %%
import pandas as pd

# %%
df = pd.read_csv('tensorflow_detection_API.csv')

# %%
df = df.iloc[0:41]

# %%
df
# Out:
#                                        Model name Speed (ms)   COCO mAP  \
# 0                  CenterNet HourGlass104 512x512         70       41.9
# 1        CenterNet HourGlass104 Keypoints 512x512         76  40.0/61.4
# 2                CenterNet HourGlass104 1024x1024        197       44.5
# 3      CenterNet HourGlass104 Keypoints 1024x1024        211  42.8/64.5
# 4               CenterNet Resnet50 V1 FPN 512x512         27       31.2
# 5     CenterNet Resnet50 V1 FPN Keypoints 512x512         30  29.3/50.7
# 6              CenterNet Resnet101 V1 FPN 512x512         34       34.2
# 7                   CenterNet Resnet50 V2 512x512         27       29.5
# 8         CenterNet Resnet50 V2 Keypoints 512x512         30  27.6/48.2
# 9               CenterNet MobileNetV2 FPN 512x512          6       23.4
# 10    CenterNet MobileNetV2 FPN Keypoints 512x512          6       41.7
# 11                        EfficientDet D0 512x512         39       33.6
# ...

# %%
df['COCO mAP'] = df['COCO mAP'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25148/2801575408.py in <module>
# ----> 1 df['COCO mAP'] = df['COCO mAP'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df.sort_values(by=df['COCO mAP'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25148/1287321973.py in <module>
# ----> 1 df.sort_values(by=df['COCO mAP'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
#    6261             # need to rewrap column in Series to apply key function
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
# ...
